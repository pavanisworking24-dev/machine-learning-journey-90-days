# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##Customizations in Matplotlib

# %% [markdown]
# #Matplotlib Markers

# %% [markdown]
# The markers module in Matplotlib helps highlight individual data points on plots, improving readability
# and aesthetics.

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y, marker='o', linestyle='-', label='Data Points')
plt.title('Simple Plot with Markers')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, marker='*', linestyle='--', color='r', label='Data Points')
plt.title('Modified Plot with Markers')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #Different Marker styles
# '.'	Point (pixel)
# ','	Pixel (very small point)
# 'o'	Circle
# 'v'	Triangle down
# '^'	Triangle up
# '<'	Triangle left
# '>'	Triangle right
# 's'	Square
# 'p'	Pentagon
# '*'	Star
# 'h'	Hexagon (pointing up)
# 'H'	Hexagon (flat top)
# '+'	Plus
# 'x'	X
# 'D'	Diamond
# 'd'	Thin diamond

# %% [markdown]
# #Line Style Refernce
# Solid line '-'m
# Dashed line '┈'
# Dash-dot line '-.'
# Dotted line ':'
# Long dashed line '--'
# Custom dash 'dotted'

# %% [markdown]
# #Colur style Refernce
# Red  'r'
# Green  'g'
# Blue  'b'
# Cyan  'c'
# Magenta  'm'
# Black  'k'
# Yellow  'y'
# Orange  'orange'
# Purple  'purple'
# White  'w'

# %%
# fmt Parameter in Matplotlib
the fmt parameter in Matplotlib is actually a combination of marker, line style, and col

# %%
x = [2, 4, 5, 1, 3]
plt.plot(x, '*-.r', ms = 20)  #ms = marker size 
plt.title('Basic graph')
plt.xlabel("x axis")
plt.show()

# %% [markdown]
# #Adding value labels on a Matplotlib Bar Chart

# %% [markdown]
# Parameters:
# x, y: Coordinates where the text will be displayed.
# s: The string (value label) to be displayed.
# ha: Horizontal alignment ('center', 'left', or 'right').
# bbox: A rectangular box surrounding the text for better visibility.

# %%
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha='center', bbox=dict(facecolor='red', alpha=0.8))
x = ['Maths', 'English', 'Science', 'Physics', 'Social']
y = [64, 42, 79, 91, 83]
plt.figure(figsize=(10, 5))
plt.bar(x, y)
add_labels(x, y)
plt.title("Student marks")
plt.xlabel("subjects")
plt.ylabel("marks")
plt.show()

# %%
#Centered Labels Inside a Rectangular Box
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i] // 2, y[i], ha='center', bbox=dict(facecolor='w', alpha=0.4))
x = ['Maths', 'English', 'Science', 'Physics', 'Social']
y = [64, 42, 79, 91, 83]
plt.figure(figsize=(10, 5))
plt.bar(x, y, color='green')
add_labels(x, y)
plt.title("Student marks")
plt.xlabel("subjects")
plt.ylabel("marks")
plt.show()

# %% [markdown]
# #Grids in Matplotlib

# %% [markdown]
# Syntax:
# matplotlib.pyplot.grid(True, color = "grey", linewidth = "1.4",  axis = ''Y", linestyle = "-.")
# Parameters:
# True/False: Specifies whether the grid should be displayed.
# color: Defines the color of the grid lines.
# linewidth: Sets the thickness of the grid lines.
# axis: Determines which axis to apply the grid ("x", "y", or both).
# linestyle: Specifies the style of the grid lines (e.g., dashed, dotted, etc.).

# %%
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)
plt.plot(x, y, color='yellow')
plt.title("Plot graph")
plt.grid(True, color='purple', linewidth='1.4', linestyle='-.')

# %% [markdown]
# #Style Plots using Matplotlib

# %%
from matplotlib import style 
data = np.random.randn(50) 
plt.style.use('Solarize_Light2') 
plt.plot(data) 
plt.show()

# %%
data = np.random.randn(50) 
plt.style.use('dark_background') 
plt.plot(data) 
plt.show()

# %%
data = np.random.randn(50) 
plt.style.use('ggplot') 
plt.plot(data, linestyle=":", linewidth=2) 
plt.show()

# %% [markdown]
# #Changing te size of figures

# %%
x = np.linspace(-5, 5, 100)
y = x**2 
plt.figure(figsize=(5, 2))
plt.plot(x, y)

plt.title('Plot of y = x^2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
x = np.linspace(-5, 5, 100)
y = x**2 
plt.figure().set_figwidth(20)
plt.plot(x, y)

plt.title('Plot of y = x^2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
x = np.linspace(-5, 5, 100)
y = x**2 
plt.figure().set_figheight(5)
plt.plot(x, y)

plt.title('Plot of y = x^2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# #Transparency of Graph Plot

# %%
alpha parameter is the most direct way to control transparency when creating plots in Matplotlib.

# %%
x = [0, 5, 10, 15]
y = [0, 1, 2, 3]

plt.plot(x, y, color='blue', alpha=0.3)
plt.title("Line plot with alpha=0.3")
plt.show()

# %%
x = ['A', 'B', 'C']
y = [5, 8, 6]

for i in range(len(x)):
    plt.bar(x[i], y[i], color='green', alpha=(i + 1)/4)

plt.title("Bar chart with varying alpha")
plt.show()

# %% [markdown]
# #Changing fonts in Matplotlib

# %%
#using fontname
from scipy import signal
t = np.linspace(0, 1, 1000, endpoint=True)
plt.plot(t, signal.square(np.pi*5*t))
plt.xlabel("Time", fontname = "Brush Script Mt", fontsize=16)
plt.ylabel("Amptitude", fontname="Brush Script MT", fontsize=16)
plt.title("Square wave", fontsize=18)
plt.show()

# %%
x = [2, 5, 1, 6, 3]
y = [1, 3, 5, 7, 2]
plt.plot(x, y)
plt.title("Population", fontname="Franklin Gothic Medium", fontsize=16)
plt.xlabel("x axis", fontname="Gabriola", fontsize=16)
plt.ylabel("y-axis", fontname="Gabriola", fontsize=16)
plt.show()

# %% [markdown]
# #using rcParams

# %%
#used if we need to apply font style to all elemnts like title, labels and ticks
import matplotlib as mp1
mp1.rcParams['font.family'] = "Comic Sans MS"
x = [1, 3, 5, 7]
y = [2, 4, 6, 8]
plt.plot(x, y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("plot graph")
plt.show()

# %% [markdown]
# #Setting Tick Labels Font Size in Matplotlib

# %% [markdown]
# 1. using font size
# 2. using set_tick_params()
# 3. using set_fontsize()
# 4. using rcParams

# %%
#using fontsize
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 50]
plt.plot(x, y)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
#using set_tick_params
fig, ax = plt.subplots()
ax.plot(x, y)
ax.tick_params(axis = 'both', which = 'major', labelsize=14)
ax.tick_params(axis = 'both', which = 'minor', labelsize=10)
plt.show()

# %%
#using set_fontsize()
fig, ax = plt.subplots()
ax.plot(x, y)

# Modify tick label font sizes individually
for label in ax.get_xticklabels():
    label.set_fontsize(12)

for label in ax.get_yticklabels():
    label.set_fontsize(12)

plt.show()

# %% [markdown]
# #using rcParams

# %%
import matplotlib as mc1
mc1.rcParams['xtick.labelsize'] = 12
mc1.rcParams['ytick.labelsize'] = 12
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %% [markdown]
# #Setting Backgorund colour of plot in Matplotlib

# %%
x = np.arange(0, 10, 0.1)
y = np.sin(x)
plt.plot(x, y)
plt.xlabel("x-axis", fontweight='bold')
plt.ylabel("sin x", fontweight='bold')
plt.title("plot")
ax = plt.gca()
ax.set_facecolor("yellow")
plt.show()

# %%
#Setting color inner and outer
x = np.arange(0, 10, 0.1)
y = np.sin(x)
plt.figure(facecolor='yellow')
plt.plot(x, y)
plt.xlabel("x-axis", fontweight='bold')
plt.title("plot")
ax = plt.gca()
ax.set_facecolor("violet")
plt.ylabel("sin x", fontweight="bold")
plt.show()

# %% [markdown]
# #Adjusting the position of axis labels in Matplotlib

# %% [markdown]
# 1.using set_xlabel() and set_ylabel()
# 2.using set_positon()
# 3.using set_rotation()

# %%
#using set_xlabel() and set_ylabel()
fig, ax = plt.subplots()
ax.plot([0,1,2], [0,1,4])
ax.set_xlabel("x-axis", labelpad=10)
ax.set_ylabel("y-axis", labelpad=30)
plt.show()

# %%
#usig set_position()
fig, ax = plt.subplots()
ax.plot([0,1,2], [0,1,4])
ax.xaxis.label.set_position((0.1, 0.5))
ax.yaxis.label.set_position([-0.2, 0.5])
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
#using set_rotation()
fig, ax = plt.subplots()
ax.plot([0,1,2], [0,1,4])
ax.set_xlabel("x-axis", labelpad=10)
ax.set_ylabel("y-axis", labelpad=10)
ax.xaxis.label.set_rotation(30)
ax.yaxis.label.set_rotation(90)
plt.show()

# %% [markdown]
# #Hiding the axis, borders and whitespaces in Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# Marks of RAM in different subjects out of 100
x = ['Science', 'Maths', 'English', 'History', 'Geography']
y = [75, 85, 88, 78, 74]

plt.bar(x, y)
plt.xlabel("Subject")
plt.ylabel("Ram's marks out of 100")
plt.show()

# %%
#Hiding axis on both sides
# Marks of RAM in different subjects out of 100
x = ['Science', 'Maths', 'English', 'History', 'Geography']
y = [75, 85, 88, 78, 74]

plt.bar(x, y)
plt.xlabel("Subject")
plt.ylabel("Ram's marks out of 100")
plt.axis("off")
plt.show()

# %%
#Hiding x-axis
# Marks of RAM in different subjects out of 100
x = ['Science', 'Maths', 'English', 'History', 'Geography']
y = [75, 85, 88, 78, 74]

plt.bar(x, y)
plt.xlabel("Subject")
plt.ylabel("Ram's marks out of 100")
plt.xticks([])
plt.show()

# %%
#Hiding y-axis
# Marks of RAM in different subjects out of 100
x = ['Science', 'Maths', 'English', 'History', 'Geography']
y = [75, 85, 88, 78, 74]

plt.bar(x, y)
plt.xlabel("Subject")
plt.ylabel("Ram's marks out of 100")
plt.yticks([])
plt.show()

# %%
#Hiding borders and whitespaces
x = ['Science', 'Maths', 'English', 'History', 'Geography']
y = [75, 85, 88, 78, 74]

plt.bar(x, y)
plt.xlabel("Subject")
plt.ylabel("Ram's marks out of 100")
plt.axis('off')

# Save figure without borders and white spaces
plt.savefig('image.png', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
#using ax.gca()
x = ['Science', 'Maths', 'English', 'History', 'Geography']
y = [75, 85, 88, 78, 74]

plt.bar(x, y)
plt.xlabel("Subject")
plt.ylabel("Ram's marks out of 100")

ax = plt.gca()
ax.xaxis.set_visible(False)  # Hide X-axis
ax.yaxis.set_visible(False)  # Hide Y-axis

plt.show()
